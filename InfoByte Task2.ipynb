# %% [markdown]
# #  Task2: Unemployement  Analysis with Python"
# #  Dataset: "Unemployement in India.csv"

# %% [markdown]
# #  Importing Required Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import datetime as dt

# %% [markdown]
# # Loading the dataset

# %%
data=pd.read_csv(r"E:\nithya\unemployment.csv")
data
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
data.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
print("NULL VALUES IN EACH COLUMNS")
data.isnull().sum()
# Out:
# NULL VALUES IN EACH COLUMNS
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %% [markdown]
# # Modified data

# %%
modified_dfmodified_df=data.dropna()
.to_csv('modified_data',index=False)
df=pd.read_csv('modified_data')
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 735     West Bengal   29-02-2020    Monthly                              7.55
# 736     West Bengal   31-03-2020    Monthly                              6.67
# 737     West Bengal   30-04-2020    Monthly                             15.63
# 738     West Bengal   31-05-2020    Monthly                             15.22
# 739     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df.columns=['Region','Date','Frequency','EstimatedUnemployedRate(%)','EstimatedEmployed','EstimatedLabourParticipatedRate(%)','Area']
df['Date']=pd.to_datetime(df['Date'],dayfirst=True)
df['Month']=df['Date'].dt.month_name()
df['Year']=df['Date'].dt.year
df
# Out:
#              Region       Date Frequency  EstimatedUnemployedRate(%)  \
# 0    Andhra Pradesh 2019-05-31   Monthly                        3.65
# 1    Andhra Pradesh 2019-06-30   Monthly                        3.05
# 2    Andhra Pradesh 2019-07-31   Monthly                        3.75
# 3    Andhra Pradesh 2019-08-31   Monthly                        3.32
# 4    Andhra Pradesh 2019-09-30   Monthly                        5.17
# ..              ...        ...       ...                         ...
# 735     West Bengal 2020-02-29   Monthly                        7.55
# 736     West Bengal 2020-03-31   Monthly                        6.67
# 737     West Bengal 2020-04-30   Monthly                       15.63
# 738     West Bengal 2020-05-31   Monthly                       15.22
# 739     West Bengal 2020-06-30   Monthly                        9.86
#
#      EstimatedEmployed  EstimatedLabourParticipatedRate(%)   Area      Month  \
# ...

# %%
print("NULL VALUES IN EACH COLUMNS AFTER MODIFYING DATA")
df.isnull().sum()
# Out:
# NULL VALUES IN EACH COLUMNS AFTER MODIFYING DATA
# Region                                0
# Date                                  0
# Frequency                             0
# EstimatedUnemployedRate(%)            0
# EstimatedEmployed                     0
# EstimatedLabourParticipatedRate(%)    0
# Area                                  0
# Month                                 0
# Year                                  0
# dtype: int64

# %%
date_emp=df.groupby(['Year'])[['EstimatedUnemployedRate(%)','EstimatedEmployed','EstimatedLabourParticipatedRate(%)']].mean()
date_emp.round(2)
# Out:
#       EstimatedUnemployedRate(%)  EstimatedEmployed  \
# Year
# 2019                         9.4         7422976.47
# 2020                        15.1         6901356.57
#
#       EstimatedLabourParticipatedRate(%)
# Year
# 2019                               43.89
# 2020                               40.89

# %%
region=df.groupby(['Region'])[['EstimatedUnemployedRate(%)','EstimatedEmployed','EstimatedLabourParticipatedRate(%)']].mean()
region.round(2)
# Out:
#                   EstimatedUnemployedRate(%)  EstimatedEmployed  \
# Region
# Andhra Pradesh                          7.48         8154093.18
# Assam                                   6.43         5354772.15
# Bihar                                  18.92        12366189.14
# Chandigarh                             15.99          316831.25
# Chhattisgarh                            9.24         4303498.57
# Delhi                                  16.50         2627512.86
# Goa                                     9.27          226308.33
# Gujarat                                 6.66        11402012.79
# Haryana                                26.28         3557072.46
# Himachal Pradesh                       18.54         1059823.71
# Jammu & Kashmir                        16.19         1799931.67
# Jharkhand                              20.58         4469240.43
# Karnataka                               6.68        10667119.29
# ...

# %% [markdown]
# # Visualizing and Analysing the data

# %%
sns.pairplot(df,hue='Region')

# %%
hm=df[['EstimatedUnemployedRate(%)','EstimatedEmployed','EstimatedLabourParticipatedRate(%)']]
corr_=hm.corr()
sns.heatmap(corr_,cmap='Blues',annot=True)
plt.show()
